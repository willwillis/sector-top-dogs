# %%
import numpy as np
import pandas as pd
import datetime
import matplotlib.pyplot as plt
# %matplotlib inline
import pickle
import os.path
import csv
from pathlib import Path
import hvplot.pandas
from sqlalchemy import create_engine

# %%
os.listdir("./pickle_stock_data2/")
#command to list files in the correct directory
# Out:
# ['A.pickle',
#  'AA.pickle',
#  'AABA.pickle',
#  'AAC.pickle',
#  'AACC.pickle',
#  'AAI.pickle',
#  'AAMC.pickle',
#  'AAN.pickle',
#  'AAOI.pickle',
#  'AAON.pickle',
#  'AAP.pickle',
#  'AAPL.pickle',
#  'AAT.pickle',
#  'AAVL.pickle',
#  'AAWW.pickle',
#  'AAXN.pickle',
#  'ABAX.pickle',
#  'ABBV.pickle',
#  'ABC.pickle',
#  'ABCB.pickle',
#  'ABCO.pickle',
#  'ABEO.pickle',
#  'ABG.pickle',
#  'ABM.pickle',
#  'ABMD.pickle',
#  'ABR.pickle',
#  'ABT.pickle',
#  'ABTX.pickle',
#  'ABUS.pickle',
#  'AC.pickle',
#  'ACA.pickle',
#  'ACAD.pickle',
#  'ACBI.pickle',
#  'ACC.pickle',
#  'ACCL.pickle',
#  'ACCO.pickle',
#  'ACE.pickle',
#  'ACF.pickle',
#  'ACFN.pickle',
#  'ACGL.pickle',
#  'ACHC.pickle',
#  'ACI.pickle',
#  'ACIA.pickle',
#  'ACIW.pickle',
#  'ACL.pickle',
#  'ACLS.pickle',
#  'ACM.pickle',
#  'ACMR.pickle',
#  'ACN.pickle',
#  'ACNB.pickle',
#  'ACOM.pickle',
#  'ACOR.pickle',
#  'ACRE.pickle',
#  'ACRS.pickle',
#  'ACS.pickle',
#  'ACT.pickle',
#  'ACTG.pickle',
#  'ACTI.pickle',
#  'ACTL.pickle',
#  'ACUR.pickle',
#  'ACV.pickle',
#  'ADBE.pickle',
#  'ADC.pickle',
#  'ADES.pickle',
#  'ADI.pickle',
#  'ADM.pickle',
#  'ADMA.pickle',
#  'ADMS.pickle',
#  'ADNT.pickle',
#  'ADP.pickle',
#  'ADPI.pickle',
#  'ADPT.pickle',
#  'ADRO.pickle',
#  'ADS.pickle',
#  'ADSK.pickle',
#  'ADSW.pickle',
#  'ADT.pickle',
#  'ADTN.pickle',
#  'ADUS.pickle',
#  'ADVM.pickle',
#  'ADXS.pickle',
#  'AE.pickle',
#  'AEE.pickle',
#  'AEGN.pickle',
#  'AEIS.pickle',
#  'AEL.pickle',
#  'AEO.pickle',
#  'AEP.pickle',
#  'AERG.pickle',
#  'AERI.pickle',
#  'AES.pickle',
#  'AET.pickle',
#  'AEZ.pickle',
#  'AFFY.pickle',
#  'AFG.pickle',
#  'AFH.pickle',
#  'AFI.pickle',
#  'AFL.pickle',
#  'AFMD.pickle',
#  'AGCO.pickle',
#  'AGE.pickle',
#  'AGEN.pickle',
#  'AGFS.pickle',
#  'AGIO.pickle',
#  'AGLE.pickle',
#  'AGM.pickle',
#  'AGN.pickle',
#  'AGNC.pickle',
#  'AGO.pickle',
#  'AGP.pickle',
#  'AGR.pickle',
#  'AGRX.pickle',
#  'AGS.pickle',
#  'AGTC.pickle',
#  'AGX.pickle',
#  'AGYS.pickle',
#  'AHC.pickle',
#  'AHG.pickle',
#  'AHH.pickle',
#  'AHII.pickle',
#  'AHL.pickle',
#  'AHT.pickle',
#  'AI.pickle',
#  'AIG.pickle',
#  'AIMC.pickle',
#  'AIMT.pickle',
#  'AINC.pickle',
#  'AINV.pickle',
#  'AIQ.pickle',
#  'AIR.pickle',
#  'AIT.pickle',
#  'AIV.pickle',
#  'AIZ.pickle',
#  'AJG.pickle',
#  'AJRD.pickle',
#  'AJX.pickle',
#  'AKAM.pickle',
#  'AKBA.pickle',
#  'AKCA.pickle',
#  'AKR.pickle',
#  'AKRX.pickle',
#  'AKS.pickle',
#  'AKTS.pickle',
#  'AL.pickle',
#  'ALB.pickle',
#  'ALBO.pickle',
#  'ALC.pickle',
#  'ALCO.pickle',
#  'ALD.pickle',
#  'ALDR.pickle',
#  'ALDX.pickle',
#  'ALE.pickle',
#  'ALEX.pickle',
#  'ALG.pickle',
#  'ALGN.pickle',
#  'ALGT.pickle',
#  'ALIM.pickle',
#  'ALJJ.pickle',
#  'ALK.pickle',
#  'ALKS.pickle',
#  'ALL.pickle',
#  'ALLE.pickle',
#  'ALLO.pickle',
#  'ALLY.pickle',
#  'ALNC.pickle',
#  'ALNY.pickle',
#  'ALO.pickle',
#  'ALOG.pickle',
#  'ALR.pickle',
#  'ALRM.pickle',
#  'ALRN.pickle',
#  'ALSK.pickle',
#  'ALSN.pickle',
#  'ALTE.pickle',
#  'ALTH.pickle',
#  'ALTR.pickle',
#  'ALV.pickle',
#  'ALX.pickle',
#  'ALXN.pickle',
#  'AM.pickle',
#  'AMAG.pickle',
#  'AMAL.pickle',
#  'AMAT.pickle',
#  'AMBA.pickle',
#  'AMBC.pickle',
#  'AMC.pickle',
#  'AMCX.pickle',
#  'AMD.pickle',
#  'AME.pickle',
#  'AMED.pickle',
#  'AMEH.pickle',
#  'AMG.pickle',
#  'AMGN.pickle',
#  'AMH.pickle',
#  'AMKR.pickle',
#  'AMLN.pickle',
#  'AMN.pickle',
#  'AMNB.pickle',
#  'AMOT.pickle',
#  'AMP.pickle',
#  'AMPE.pickle',
#  'AMPH.pickle',
#  'AMPL.pickle',
#  'AMR.pickle',
#  'AMRC.pickle',
#  'AMRS.pickle',
#  'AMRX.pickle',
#  'AMSC.pickle',
#  'AMSF.pickle',
#  'AMSWA.pickle',
#  'AMT.pickle',
#  'AMTD.pickle',
#  'AMV.pickle',
#  'AMWD.pickle',
#  'AMZN.pickle',
#  'AN.pickle',
#  'ANAB.pickle',
#  'ANAT.pickle',
#  'ANDE.pickle',
#  'ANEN.pickle',
#  'ANET.pickle',
#  'ANF.pickle',
#  'ANGI.pickle',
#  'ANGO.pickle',
#  'ANH.pickle',
#  'ANIK.pickle',
#  'ANIP.pickle',
#  'ANR.pickle',
#  'ANSS.pickle',
#  'ANTH.pickle',
#  'ANTM.pickle',
#  'ANV.pickle',
#  'AOBC.pickle',
#  'AON.pickle',
#  'AOS.pickle',
#  'AOSL.pickle',
#  'AP.pickle',
#  'APA.pickle',
#  'APAM.pickle',
#  'APC.pickle',
#  'APD.pickle',
#  'APEI.pickle',
#  'APFC.pickle',
#  'APH.pickle',
#  'APIC.pickle',
#  'APKT.pickle',
#  'APLE.pickle',
#  'APLS.pickle',
#  'APOG.pickle',
#  'APPF.pickle',
#  'APPS.pickle',
#  'APTS.pickle',
#  'APTV.pickle',
#  'APTX.pickle',
#  'APVO.pickle',
#  'APY.pickle',
#  'AQ.pickle',
#  'AQMS.pickle',
#  'AQST.pickle',
#  'AQUA.pickle',
#  'AR.pickle',
#  'ARA.pickle',
#  'ARAY.pickle',
#  'ARB.pickle',
#  'ARBA.pickle',
#  'ARC.pickle',
#  'ARCB.pickle',
#  'ARCC.pickle',
#  'ARCH.pickle',
#  'ARCT.pickle',
#  'ARCW.pickle',
#  'ARD.pickle',
#  'ARDNA.pickle',
#  'ARDX.pickle',
#  'ARE.pickle',
#  'AREX.pickle',
#  'ARGO.pickle',
#  'ARI.pickle',
#  'ARII.pickle',
#  'ARJ.pickle',
#  'ARL.pickle',
#  'ARMK.pickle',
#  'ARNA.pickle',
#  'ARNC.pickle',
#  'AROC.pickle',
#  'AROPQ.pickle',
#  'AROW.pickle',
#  'ARQL.pickle',
#  'ARR.pickle',
#  'ARRY.pickle',
#  'ARST.pickle',
#  'ART.pickle',
#  'ARTC.pickle',
#  'ARTL.pickle',
#  'ARTNA.pickle',
#  'ARW.pickle',
#  'ARWR.pickle',
#  'ARYX.pickle',
#  'ASB.pickle',
#  'ASC.pickle',
#  'ASCA.pickle',
#  'ASCMA.pickle',
#  'ASFI.pickle',
#  'ASGN.pickle',
#  'ASH.pickle',
#  'ASIX.pickle',
#  'ASMB.pickle',
#  'ASNA.pickle',
#  'ASPN.pickle',
#  'ASPS.pickle',
#  'ASRT.pickle',
#  'ASTE.pickle',
#  'ASTI.pickle',
#  'ASTX.pickle',
#  'ASUR.pickle',
#  'ASYS.pickle',
#  'AT.pickle',
#  'ATAC.pickle',
#  'ATB.pickle',
#  'ATEC.pickle',
#  'ATEN.pickle',
#  'ATGE.pickle',
#  'ATH.pickle',
#  'ATHN.pickle',
#  'ATHX.pickle',
#  'ATI.pickle',
#  'ATKR.pickle',
#  'ATLO.pickle',
#  'ATLS.pickle',
#  'ATMI.pickle',
#  'ATNI.pickle',
#  'ATNM.pickle',
#  'ATNX.pickle',
#  'ATO.pickle',
#  'ATR.pickle',
#  'ATRA.pickle',
#  'ATRC.pickle',
#  'ATRI.pickle',
#  'ATRO.pickle',
#  'ATROB.pickle',
#  'ATRS.pickle',
#  'ATSG.pickle',
#  'ATU.pickle',
#  'ATVI.pickle',
#  'ATW.pickle',
#  'ATX.pickle',
#  'AUBN.pickle',
#  'AUMN.pickle',
#  'AUTH.pickle',
#  'AVA.pickle',
#  'AVAV.pickle',
#  'AVB.pickle',
#  'AVD.pickle',
#  'AVEO.pickle',
#  'AVG.pickle',
#  'AVGO.pickle',
#  'AVGR.pickle',
#  'AVID.pickle',
#  'AVLR.pickle',
#  'AVNW.pickle',
#  'AVP.pickle',
#  'AVRO.pickle',
#  'AVT.pickle',
#  'AVTR.pickle',
#  'AVX.pickle',
#  'AVXL.pickle',
#  'AVY.pickle',
#  'AVYA.pickle',
#  'AWI.pickle',
#  'AWK.pickle',
#  'AWR.pickle',
#  'AWRE.pickle',
#  'AX.pickle',
#  'AXAS.pickle',
#  'AXDX.pickle',
#  'AXE.pickle',
#  'AXGN.pickle',
#  'AXL.pickle',
#  'AXON.pickle',
#  'AXP.pickle',
#  'AXR.pickle',
#  'AXS.pickle',
#  'AXTA.pickle',
#  'AXTI.pickle',
#  'AYE.pickle',
#  'AYI.pickle',
#  'AYR.pickle',
#  'AYX.pickle',
#  'AZO.pickle',
#  'AZPN.pickle',
#  'AZZ.pickle',
#  'B.pickle',
#  'BA.pickle',
#  'BABY.pickle',
#  'BAC.pickle',
#  'BAH.pickle',
#  'BANC.pickle',
#  'BANF.pickle',
#  'BANR.pickle',
#  'BAS.pickle',
#  'BATRA.pickle',
#  'BATRK.pickle',
#  'BAX.pickle',
#  'BBBY.pickle',
#  'BBGI.pickle',
#  'BBSI.pickle',
#  'BBT.pickle',
#  'BBW.pickle',
#  'BBX.pickle',
#  'BBY.pickle',
#  'BC.pickle',
#  'BCBP.pickle',
#  'BCC.pickle',
#  'BCEI.pickle',
#  'BCML.pickle',
#  'BCO.pickle',
#  'BCOR.pickle',
#  'BCOV.pickle',
#  'BCPC.pickle',
#  'BCRH.pickle',
#  'BCRX.pickle',
#  'BDC.pickle',
#  'BDGE.pickle',
#  'BDK.pickle',
#  'BDN.pickle',
#  'BDSI.pickle',
#  'BDX.pickle',
#  'BEAT.pickle',
#  'BEBE.pickle',
#  'BEC.pickle',
#  'BECN.pickle',
#  'BELFB.pickle',
#  'BEN.pickle',
#  'BERK.pickle',
#  'BERY.pickle',
#  'BEXP.pickle',
#  'BEZ.pickle',
#  'BFA.pickle',
#  'BFAM.pickle',
#  'BFB.pickle',
#  'BFIN.pickle',
#  'BFS.pickle',
#  'BFST.pickle',
#  'BG.pickle',
#  'BGCP.pickle',
#  'BGFV.pickle',
#  'BGG.pickle',
#  'BGMD.pickle',
#  'BGS.pickle',
#  'BGSF.pickle',
#  'BH.pickle',
#  'BHB.pickle',
#  'BHE.pickle',
#  'BHF.pickle',
#  'BHGE.pickle',
#  'BHI.pickle',
#  'BHLB.pickle',
#  'BHR.pickle',
#  'BHVN.pickle',
#  'BID.pickle',
#  'BIG.pickle',
#  'BIIB.pickle',
#  'BIO.pickle',
#  'BIOL.pickle',
#  'BIOS.pickle',
#  'BIVV.pickle',
#  'BJ.pickle',
#  'BJRI.pickle',
#  'BK.pickle',
#  'BKC.pickle',
#  'BKCC.pickle',
#  'BKD.pickle',
#  'BKE.pickle',
#  'BKH.pickle',
#  'BKI.pickle',
#  'BKNG.pickle',
#  'BKR.pickle',
#  'BKS.pickle',
#  'BKU.pickle',
#  'BL.pickle',
#  'BLBD.pickle',
#  'BLC.pickle',
#  'BLCM.pickle',
#  'BLD.pickle',
#  'BLDR.pickle',
#  'BLK.pickle',
#  'BLKB.pickle',
#  'BLL.pickle',
#  'BLMN.pickle',
#  'BLUE.pickle',
#  'BLX.pickle',
#  'BMC.pickle',
#  'BMCH.pickle',
#  'BMI.pickle',
#  'BMRC.pickle',
#  'BMRN.pickle',
#  'BMTC.pickle',
#  'BMTI.pickle',
#  'BMY.pickle',
#  'BNE.pickle',
#  'BNED.pickle',
#  'BNFT.pickle',
#  'BNHN.pickle',
#  'BNK.pickle',
#  'BNT.pickle',
#  'BOCH.pickle',
#  'BODY.pickle',
#  'BOH.pickle',
#  'BOJA.pickle',
#  'BOKF.pickle',
#  'BOMN.pickle',
#  'BOOM.pickle',
#  'BOOT.pickle',
#  'BOX.pickle',
#  'BPFH.pickle',
#  'BPMC.pickle',
#  'BPOP.pickle',
#  'BPRN.pickle',
#  'BPTH.pickle',
#  'BR.pickle',
#  'BRC.pickle',
#  'BRE.pickle',
#  'BREW.pickle',
#  'BRG.pickle',
#  'BRID.pickle',
#  'BRKB.pickle',
#  'BRKL.pickle',
#  'BRKS.pickle',
#  'BRL.pickle',
#  'BRO.pickle',
#  'BRT.pickle',
#  'BRX.pickle',
#  'BRY.pickle',
#  'BSET.pickle',
#  'BSF.pickle',
#  'BSIG.pickle',
#  'BSRR.pickle',
#  'BSTC.pickle',
#  'BSX.pickle',
#  'BTFG.pickle',
#  'BTH.pickle',
#  'BTN.pickle',
#  'BTU.pickle',
#  'BTX.pickle',
#  'BUF.pickle',
#  'BUFF.pickle',
#  'BURL.pickle',
#  'BUSE.pickle',
#  'BV.pickle',
#  'BW.pickle',
#  'BWA.pickle',
#  'BWB.pickle',
#  'BWEN.pickle',
#  'BWFG.pickle',
#  'BWXT.pickle',
#  'BXC.pickle',
#  'BXG.pickle',
#  'BXMT.pickle',
#  'BXP.pickle',
#  'BXS.pickle',
#  'BY.pickle',
#  'BYD.pickle',
#  'BZH.pickle',
#  'C.pickle',
#  'CA.pickle',
#  'CAAS.pickle',
#  'CAB.pickle',
#  'CABO.pickle',
#  'CAC.pickle',
#  'CACC.pickle',
#  'CACH.pickle',
#  'CACI.pickle',
#  'CADE.pickle',
#  'CADX.pickle',
#  'CAG.pickle',
#  'CAH.pickle',
#  'CAI.pickle',
#  'CAKE.pickle',
#  'CAL.pickle',
#  'CALA.pickle',
#  'CALM.pickle',
#  'CAMP.pickle',
#  'CAO.pickle',
#  'CAP.pickle',
#  'CAR.pickle',
#  'CARA.pickle',
#  'CARB.pickle',
#  'CARO.pickle',
#  'CARS.pickle',
#  'CASA.pickle',
#  'CASH.pickle',
#  'CASI.pickle',
#  'CASS.pickle',
#  'CASY.pickle',
#  'CAT.pickle',
#  'CATB.pickle',
#  'CATC.pickle',
#  'CATM.pickle',
#  'CATO.pickle',
#  'CATS.pickle',
#  'CATY.pickle',
#  'CB.pickle',
#  'CBAY.pickle',
#  'CBB.pickle',
#  'CBE.pickle',
#  'CBFV.pickle',
#  'CBH.pickle',
#  'CBI.pickle',
#  'CBIO.pickle',
#  'CBKN.pickle',
#  'CBL.pickle',
#  'CBLI.pickle',
#  'CBLK.pickle',
#  'CBM.pickle',
#  'CBMG.pickle',
#  'CBNK.pickle',
#  'CBOE.pickle',
#  'CBOU.pickle',
#  'CBPX.pickle',
#  'CBRL.pickle',
#  'CBS.pickle',
#  'CBSH.pickle',
#  'CBT.pickle',
#  'CBTX.pickle',
#  'CBU.pickle',
#  'CBZ.pickle',
#  'CC.pickle',
#  'CCB.pickle',
#  'CCBG.pickle',
#  'CCC.pickle',
#  'CCE.pickle',
#  'CCF.pickle',
#  'CCGM.pickle',
#  'CCI.pickle',
#  'CCIX.pickle',
#  'CCK.pickle',
#  'CCL.pickle',
#  'CCMP.pickle',
#  'CCNE.pickle',
#  'CCO.pickle',
#  'CCOI.pickle',
#  'CCRN.pickle',
#  'CCS.pickle',
#  'CCXI.pickle',
#  'CDAY.pickle',
#  'CDE.pickle',
#  'CDEV.pickle',
#  'CDK.pickle',
#  'CDLX.pickle',
#  'CDNA.pickle',
#  'CDNS.pickle',
#  'CDR.pickle',
#  'CDTX.pickle',
#  'CDVIQ.pickle',
#  'CDW.pickle',
#  'CDXC.pickle',
#  'CDXS.pickle',
#  'CDZI.pickle',
#  'CE.pickle',
#  'CEB.pickle',
#  'CEC.pickle',
#  'CECE.pickle',
#  'CECO.pickle',
#  'CEG.pickle',
#  'CEIX.pickle',
#  'CELC.pickle',
#  'CELG.pickle',
#  'CELL.pickle',
#  'CENT.pickle',
#  'CENTA.pickle',
#  'CENX.pickle',
#  'CERN.pickle',
#  'CERS.pickle',
#  'CETV.pickle',
#  'CF.pickle',
#  'CFC.pickle',
#  'CFFI.pickle',
#  'CFFN.pickle',
#  'CFG.pickle',
#  'CFI.pickle',
#  'CFMS.pickle',
#  'CFNB.pickle',
#  'CFR.pickle',
#  'CFX.pickle',
#  'CG.pickle',
#  'CGA.pickle',
#  'CGC.pickle',
#  'CGNX.pickle',
#  'CHCT.pickle',
#  'CHD.pickle',
#  'CHDN.pickle',
#  'CHE.pickle',
#  'CHEF.pickle',
#  'CHFC.pickle',
#  'CHFN.pickle',
#  'CHG.pickle',
#  'CHGG.pickle',
#  'CHH.pickle',
#  'CHIC.pickle',
#  'CHK.pickle',
#  'CHMA.pickle',
#  'CHMG.pickle',
#  'CHMI.pickle',
#  'CHRA.pickle',
#  'CHRS.pickle',
#  'CHRW.pickle',
#  'CHS.pickle',
#  'CHSP.pickle',
#  'CHTR.pickle',
#  'CHUY.pickle',
#  'CHZ.pickle',
#  'CI.pickle',
#  'CIA.pickle',
#  'CIEN.pickle',
#  'CIM.pickle',
#  'CINF.pickle',
#  'CIO.pickle',
#  'CIR.pickle',
#  'CISN.pickle',
#  'CIT.pickle',
#  'CIVB.pickle',
#  'CIX.pickle',
#  'CIZN.pickle',
#  'CJ.pickle',
#  'CKH.pickle',
#  'CKR.pickle',
#  'CL.pickle',
#  'CLAR.pickle',
#  'CLB.pickle',
#  'CLBK.pickle',
#  'CLC.pickle',
#  'CLCT.pickle',
#  'CLDR.pickle',
#  'CLDT.pickle',
#  'CLDX.pickle',
#  'CLF.pickle',
#  'CLFD.pickle',
#  'CLGX.pickle',
#  'CLH.pickle',
#  'CLI.pickle',
#  'CLNC.pickle',
#  'CLNY.pickle',
#  'CLP.pickle',
#  'CLPR.pickle',
#  'CLR.pickle',
#  'CLSD.pickle',
#  'CLUB.pickle',
#  'CLVS.pickle',
#  'CLW.pickle',
#  'CLWR.pickle',
#  'CLX.pickle',
#  'CLXT.pickle',
#  'CMA.pickle',
#  'CMC.pickle',
#  'CMCO.pickle',
#  'CMCSA.pickle',
#  'CMD.pickle',
#  'CME.pickle',
#  'CMG.pickle',
#  'CMI.pickle',
#  'CMLS.pickle',
#  'CMO.pickle',
#  'CMP.pickle',
#  'CMPR.pickle',
#  'CMRE.pickle',
#  'CMRX.pickle',
#  'CMS.pickle',
#  'CMT.pickle',
#  'CMTL.pickle',
#  'CMVT.pickle',
#  'CNA.pickle',
#  'CNAT.pickle',
#  'CNBKA.pickle',
#  'CNC.pickle',
#  'CNCE.pickle',
#  'CNDT.pickle',
#  'CNH.pickle',
#  'CNK.pickle',
#  'CNMD.pickle',
#  'CNNE.pickle',
#  'CNO.pickle',
#  'CNOB.pickle',
#  'CNP.pickle',
#  'CNS.pickle',
#  'CNSL.pickle',
#  'CNST.pickle',
#  'CNTY.pickle',
#  'CNU.pickle',
#  'CNX.pickle',
#  'CNXN.pickle',
#  'CNXT.pickle',
#  'COBZ.pickle',
#  'CODE.pickle',
#  'CODI.pickle',
#  'COF.pickle',
#  'COG.pickle',
#  'COHN.pickle',
#  'COHR.pickle',
#  'COHU.pickle',
#  'COL.pickle',
#  'COLB.pickle',
#  'COLD.pickle',
#  'COLL.pickle',
#  'COLM.pickle',
#  'COMM.pickle',
#  'CONE.pickle',
#  'CONN.pickle',
#  'COO.pickle',
#  'COOP.pickle',
#  'COP.pickle',
#  'COR.pickle',
#  'CORE.pickle',
#  'CORR.pickle',
#  'CORT.pickle',
#  'COST.pickle',
#  'COTV.pickle',
#  'COTY.pickle',
#  'COUP.pickle',
#  'COV.pickle',
#  'COWN.pickle',
#  'CPA.pickle',
#  'CPB.pickle',
#  'CPE.pickle',
#  'CPF.pickle',
#  'CPICQ.pickle',
#  'CPK.pickle',
#  'CPLG.pickle',
#  'CPN.pickle',
#  'CPO.pickle',
#  'CPRT.pickle',
#  'CPRX.pickle',
#  'CPS.pickle',
#  'CPSI.pickle',
#  'CPSS.pickle',
#  'CPST.pickle',
#  'CPT.pickle',
#  'CPTS.pickle',
#  'CPWR.pickle',
#  'CPX.pickle',
#  'CR.pickle',
#  'CRA.pickle',
#  'CRAI.pickle',
#  'CRAY.pickle',
#  'CRBC.pickle',
#  'CRBP.pickle',
#  'CRC.pickle',
#  'CRCM.pickle',
#  'CRDB.pickle',
#  'CRDN.pickle',
#  'CRED.pickle',
#  'CREE.pickle',
#  'CRI.pickle',
#  'CRIS.pickle',
#  'CRK.pickle',
#  'CRL.pickle',
#  'CRM.pickle',
#  'CRMD.pickle',
#  'CRMT.pickle',
#  'CRNX.pickle',
#  'CROX.pickle',
#  'CRR.pickle',
#  'CRS.pickle',
#  'CRTX.pickle',
#  'CRUS.pickle',
#  'CRVL.pickle',
#  'CRVS.pickle',
#  'CRY.pickle',
#  'CRZO.pickle',
#  'CSA.pickle',
#  'CSC.pickle',
#  'CSCO.pickle',
#  'CSE.pickle',
#  'CSFL.pickle',
#  'CSGP.pickle',
#  'CSGS.pickle',
#  'CSII.pickle',
#  'CSKI.pickle',
#  'CSL.pickle',
#  'CSLT.pickle',
#  'CSOD.pickle',
#  'CSR.pickle',
#  'CSRA.pickle',
#  'CSS.pickle',
#  'CSTE.pickle',
#  'CSTR.pickle',
#  'CSU.pickle',
#  'CSV.pickle',
#  'CSWC.pickle',
#  'CSWI.pickle',
#  'CSX.pickle',
#  'CTAS.pickle',
#  'CTB.pickle',
#  'CTBI.pickle',
#  'CTBK.pickle',
#  'CTG.pickle',
#  'CTGO.pickle',
#  'CTIC.pickle']

# %%
engine = create_engine("postgresql://postgres:13artimaeus@localhost:5432/russell3000stockdata")
#creates the engine for this database connection, edit this for your local connection

# %%
n=1
for filename in os.listdir("./pickle_stock_data2/")[3000:]:
    ticker = os.path.splitext(filename)[0]
    current_df = pd.read_pickle(f"./pickle_stock_data2/{ticker}.pickle")
    current_df["Ticker"] = ticker
    current_df.to_sql("ticker_data", engine, if_exists = 'append' )
    print(n, ' ', ticker, end = ',')
    n+=1
    
#Iterates over the first N number of files in the directory. 
#Splits the filename keeping only the portion before the extension
#Reads in the serialized data file for that ticker
#Creates an additional DB column for that ticker to be stored
#Writes/appends the SQL ticker data file
#Prints to check for correct debug
# Out:
# 1   SEM,2   SEMG,3   SENEA,4   SENS,5   SERV,6   SF,7   SFBS,8   SFD,9   SFE,10   SFG,11   SFL,12   SFLY,13   SFM,14   SFNC,15   SFST,16   SFY,17   SGA,18   SGC,19   SGEN,20   SGH,21   SGI,22   SGMO,23   SGMS,24   SGRY,25   SHAK,26   SHBI,27   SHEN,28   SHF,29   SHFL,30   SHLM,31   SHLO,32   SHO,33   SHOO,34   SHOS,35   SHS,36   SHW,37   SIBN,38   SIE,39   SIEB,40   SIEN,41   SIF,42   SIG,43   SIGA,44   SIGI,45   SII,46   SILC,47   SINT,48   SIRI,49   SITC,50   SITE,51   SIVB,52   SIX,53   SIXD,54   SJI,55   SJM,56   SJR,57   SJW,58   SKS,59   SKT,60   SKX,61   SKY,62   SKYW,63   SLAB,64   SLB,65   SLCA,66   SLCT,67   SLDB,68   SLE,69   SLG,70   SLGN,71   SLM,72   SLP,73   SLRC,74   SLTM,75   SM,76   SMA,77   SMBC,78   SMBK,79   SMG,80   SMHI,81   SMMF,82   SMP,83   SMPL,84   SMRT,85   SMSI,86   SMTA,87   SMTC,88   SMTS,89   SNA,90   SNCI,91   SNCR,92   SND,93   SNDR,94   SNDX,95   SNH,96   SNMX,97   SNNA,98   SNPS,99   SNR,100   SNSS,101   SNTS,102   SNV,103   SNX,104   SO,105   SOA,106   SOHU,107   SOI,108   SOMX,109   SON,110   SONA,111   SONC,112   SONE,113   SONO,114   SOV,115   SP,116   SPAR,117   SPB,118   SPDC,119   SPEC,120   SPG,121   SPGI,122   SPKE,123   SPLK,124   SPMD,125   SPN,126   SPNE,127   SPNS,128   SPOK,129   SPPI,130   SPR,131   SPRO,132   SPRT,133   SPSC,134   SPTN,135   SPWH,136   SPWR,137   SPXC,138   SQ,139   SR,140   SRC,141   SRCE,142   SRCI,143   SRCL,144   SRDX,145   SRE,146   SREV,147   SRG,148   SRI,149   SRNE,150   SRPT,151   SRRK,152   SRT,153   SRX,154   SRZ,155   SSB,156   SSD,157   SSI,158   SSNC,159   SSP,160   SSTI,161   SSTK,162   SSYS,163   ST,164   STAG,165   STAR,166   STAY,167   STBA,168   STBC,169   STC,170   STE,171   STEI,172   STEL,173   STFC,174   STI,175   STIM,176   STL,177   STLD,178   STLY,179   STML,180   STMP,181   STNG,182   STOR,183   STR,184   STRA,185   STRI,186   STRS,187   STRT,188   STS,189   STSA,190   STT,191   STU,192   STWD,193   STX,194   STXB,195   STXS,196   STZ,197   SUG,198   SUI,199   SUM,200   SUMR,201   SUN,202   SUNH,203   SUNS,204   SUP,205   SUPN,206   SUPR,207   SUPX,208   SUR,209   SURF,210   SURG,211   SVC,212   SVMK,213   SVR,214   SVRA,215   SVVC,216   SWC,217   SWCH,218   SWI,219   SWK,220   SWKS,221   SWM,222   SWN,223   SWSH,224   SWX,225   SXC,226   SXI,227   SXT,228   SY,229   SYBT,230   SYBX,231   SYCRF,232   SYF,233   SYK,234   SYKE,235   SYMC,236   SYMM,237   SYN,238   SYNA,239   SYNC,240   SYNH,241   SYNL,242   SYPR,243   SYRS,244   SYX,245   T,246   TACO,247   TAL,248   TALO,249   TAM,250   TAP,251   TAST,252   TAT,253   TAX,254   TBBK,255   TBI,256   TBIO,257   TBK,258   TBL,259   TBNK,260   TBPH,261   TCAP,262   TCB,263   TCBI,264   TCBK,265   TCDA,266   TCF,267   TCFC,268   TCMD,269   TCO,270   TCPC,271   TCRD,272   TCS,273   TCX,274   TDC,275   TDG,276   TDOC,277   TDS,278   TDW,279   TDY,280   TEA,281   TEAM,282   TEAR,283   TECD,284   TECH,285   TEG,286   TELL,287   TEN,288   TENB,289   TER,290   TERP,291   TESS,292   TETAA,293   TETAB,294   TEX,295   TFSL,296   TFX,297   TG,298   TGH,299   TGI,300   TGNA,301   TGT,302   TGTX,303   THC,304   THFF,305   THG,306   THI,307   THO,308   THOR,309   THR,310   THRM,311   THS,312   TIE,313   TIF,314   TIN,315   TIPT,316   TISI,317   TITN,318   TJX,319   TK,320   TKR,321   TLAB,322   TLB,323   TLGT,324   TLK,325   TLRA,326   TLRD,327   TLYS,328   TMA,329   TMHC,330   TMK,331   TMO,332   TMP,333   TMR,334   TMS,335   TMST,336   TMUS,337   TNAV,338   TNB,339   TNC,340   TNDM,341   TNET,342   TNS,343   TOCA,344   TOL,345   TORC,346   TOWN,347   TOWR,348   TPB,349   TPC,350   TPCO,351   TPGI,352   TPH,353   TPHS,354   TPIC,355   TPR,356   TPRE,357   TPX,358   TR,359   TRA,360   TRAD,361   TRC,362   TRCB,363   TRCO,364   TREC,365   TREE,366   TREX,367   TRGP,368   TRHC,369   TRI,370   TRIP,371   TRK,372   TRMB,373   TRMK,374   TRNO,375   TRNX,376   TROV,377   TROW,378   TROX,379   TRS,380   TRST,381   TRTN,382   TRTX,383   TRU,384   TRUE,385   TRUP,386   TRV,387   TRVN,388   TRW,389   TRXC,390   ...

# %%
#ticker = 'AA'
#test_df = pd.read_pickle(f"./pickle_stock_data2/{ticker}.pickle")
#test_df["Ticker"] = ticker

# %%
#test_df.to_sql("ticker_data", engine, if_exists = 'append' )

# %%
#print(test_df.head())
# Out:
#                  Open       High        Low  Adj Close     Volume Ticker
# Date
# 2005-01-03  76.415398  76.415398  74.276733  60.909332  2000700.0     AA
# 2005-01-04  74.228668  74.444939  72.690750  59.808704  2644400.0     AA
# 2005-01-05  73.123291  73.700012  71.585373  59.454903  2739000.0     AA
# 2005-01-06  73.291496  74.108521  72.834930  59.710407  2578600.0     AA
# 2005-01-07  73.099258  74.492996  73.027168  60.319706  2389200.0     AA

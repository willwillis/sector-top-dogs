# %%
import numpy as np
import pandas as pd
import os.path
from os import path
import csv
from pathlib import Path
import pickle
import os
from datetime import datetime

parent = None

def composition_df_from_csv(file,composition_label):
    if path.exists(file):
        prices = pd.read_csv(csv_file, error_bad_lines=False, header=10)
        cols = prices.columns
        prices[cols] = prices[cols].replace({'\$': '', ',': ''}, regex=True)
        prices.dropna(inplace=True)
        prices['composition_label'] = composition_label
        return prices
    else:
        print(f"{file} doesn't exist")
           

base_dir = "../../data/rawdata/fund-composition-as-of/"

for file in os.listdir(base_dir):
    print(f"evaluating {file}")
    if file.endswith('.csv'):
        print(f"\tprocessing {file}")
        date_str = file.replace('.csv','')
        composition_label = datetime.strptime(date_str, '%Y%m%d').strftime('%m/%d/%Y')
        csv_file = base_dir + file
        parent = composition_df_from_csv(csv_file,composition_label)
        break
        
parent
# Out:
# evaluating .~lock.20060929.csv#
# evaluating 20060929.csv
# 	processing 20060929.csv
#       Ticker                              Name Asset Class  Weight (%)  Price  \
# 0     P5N994              Petrocorp Inc Escrow      Equity        0.00   0.00
# 1        TBV    TIENS BIOTECH GROUP (USA) INC.      Equity        0.00   2.90
# 2        CIX           COMPX INTERNATIONAL INC      Equity        0.00  15.59
# 3       TTES               T-3 ENERGY SERVICES      Equity        0.00  20.07
# 4       PGSW  PEGASUS WIRELESS CORP NV COM NEW      Equity        0.00   0.61
# ...      ...                               ...         ...         ...    ...
# 2955    MSFT                    MICROSOFT CORP      Equity        1.65  27.33
# 2956     BAC              BANK OF AMERICA CORP      Equity        1.66  53.57
# 2957    0R01                     CITIGROUP INC      Equity        1.68  49.67
# 2958     GEC                  GENERAL ELECTRIC      Equity        2.49  35.30
# 2959     XOM                  EXXON MOBIL CORP      Equity        2.76  67.10
#
#           Shares Market Value Notional Value Sector    SEDOL          ISIN  \
# 0        1248.00         0.12           0.00      -        -  US71645N9947
# 1         550.00      1595.00        1595.00      -  2975968  US88650T1043
# 2         247.00      3850.73        3851.00      -  2201908  US20563P1012
# 3         221.00      4435.47        4435.00      -  2828125  US87306E1073
# 4        8500.00      5185.00        5185.00      -  B1L5141  US70558E2072
# ...          ...          ...            ...    ...      ...           ...
# 2955  1398722.00  38227072.26    38227072.00      -  2588173  US5949181045
# 2956   719216.00  38528401.11    38528401.00      -  BHZL9B0  US0605051046
# 2957   783475.00  38915203.25    38915203.00      -  B0ZC1L8  US1729671016
# 2958  1638782.00  57849004.59    57849005.00      -  5254471  US3696041033
# 2959   953526.00  63981594.60    63981595.00      -  2326618  US30231G1022
#
#                               Exchange composition_label
# 0     Non-Nms Quotation Service (Nnqs)        09/29/2006
# 1                         Nyse Mkt Llc        09/29/2006
# 2                         Nyse Mkt Llc        09/29/2006
# 3                               NASDAQ        09/29/2006
# 4     Non-Nms Quotation Service (Nnqs)        09/29/2006
# ...                                ...               ...
# 2955                            NASDAQ        09/29/2006
# 2956                SIX Swiss Exchange        09/29/2006
# 2957             London Stock Exchange        09/29/2006
# 2958             Deutsche Boerse Xetra        09/29/2006
# 2959      New York Stock Exchange Inc.        09/29/2006
#
# [2960 rows x 13 columns]
